# %% [markdown]
# # Foundations of AI & ML
# ## Session 06
# ### CaseStudy
# ### Applying PCA, ISOMAP, LLE, T-SNE on data

# %% [markdown]
# ### Step 1
# We read the entire file into a list of lines, converting everything to lowercase as well as remove trailing and leading whitespace.

# %%
wp_text_stage0 = [line.strip().lower() for line in open("../Datasets/War_And_Peace.txt",encoding="utf8")]
print(wp_text_stage0[4000:4010])
# Out:
# ['“you must look for husbands for them whether you like it or not....”', '', '“well,” said she, “how’s my cossack?” (márya dmítrievna', 'always called natásha a cossack) and she stroked the child’s arm as', 'she came up fearless and gay to kiss her hand. “i know she’s a scamp', 'of a girl, but i like her.”', '', 'she took a pair of pear-shaped ruby earrings from her huge reticule and,', 'having given them to the rosy natásha, who beamed with the pleasure', 'of her saint’s-day fete, turned away at once and addressed herself to']

# %% [markdown]
# ### Step 2
# We combine them into one gigantic string

# %%
wp_text_stage1 = ' '.join(wp_text_stage0)

# %%
print(len(wp_text_stage1))
print(wp_text_stage1[40000:40200])
# Out:
# 3224829
# rove my devotion to you and how i respect your father’s memory, i will do the impossible—your son shall be transferred to the guards. here is my hand on it. are you satisfied?”  “my dear benefactor! t

# %% [markdown]
# ### Step 3
# We break down this gigantic string into sentences

# %%
from nltk.tokenize import sent_tokenize
wp_text_stage2 = sent_tokenize(wp_text_stage1)

# %%
print(len(wp_text_stage2))
print(wp_text_stage2[5000:5010])
# Out:
# 26313
# ['after tea, the company went into the sitting room and princess mary was asked to play on the clavichord.', 'anatole, laughing and in high spirits, came and leaned on his elbows, facing her and beside mademoiselle bourienne.', 'princess mary felt his look with a painfully joyous emotion.', 'her favorite sonata bore her into a most intimately poetic world and the look she felt upon her made that world still more poetic.', 'but anatole’s expression, though his eyes were fixed on her, referred not to her but to the movements of mademoiselle bourienne’s little foot, which he was then touching with his own under the clavichord.', 'mademoiselle bourienne was also looking at princess mary, and in her lovely eyes there was a look of fearful joy and hope that was also new to the princess.', '“how she loves me!” thought princess mary.', '“how happy i am now, and how happy i may be with such a friend and such a husband!', 'husband?', 'can it be possible?” she thought, not daring to look at his face, but still feeling his eyes gazing at her.']

# %% [markdown]
# So we have about 26k sentences, in the tome. We now take each sentence and clean it up as below:
#  * replace all non-alphanumeric characters by space
#  * split each sentence on whitespace
#  * in each sentence drop words that are less than 3 letters long and are part of fluff words

# %% [markdown]
# ### Step 4
# We read the entire contents the fluff file into a set. As mentioned earlier a set is much faster for checking membership

# %%
fluff = set([line.strip() for line in open("../Datasets/stoplist.txt")])

# %% [markdown]
# ### Step 5
# Replace all non-alphanumeric characters by space

# %%
import re
only_alnum = re.compile(r"[^\w]+") ## \w => unicode alphabet
#only_alnum = re.compile(r"[^a-z0-9]") --> This will remove accented characters which are part of many names!

## Replaces one or more occurrence of any characters other unicode alphabets and numbers
def cleanUp(s):
    return re.sub(only_alnum, " ", s).strip()
wp_text_stage3 = [cleanUp(s) for s in wp_text_stage2]
print(wp_text_stage3[4000:4010])
# Out:
# ['the whole air reeked with smoke', 'the excited faces of the soldiers were blackened with it', 'some were using their ramrods others putting powder on the touchpans or taking charges from their pouches while others were firing though who they were firing at could not be seen for the smoke which there was no wind to carry away', 'a pleasant humming and whistling of bullets were often heard', 'what is this thought prince andrew approaching the crowd of soldiers', 'it can t be an attack for they are not moving it can t be a square for they are not drawn up for that the commander of the regiment a thin feeble looking old man with a pleasant smile his eyelids drooping more than half over his old eyes giving him a mild expression rode up to bagratión and welcomed him as a host welcomes an honored guest', 'he reported that his regiment had been attacked by french cavalry and that though the attack had been repulsed he had lost more than half his men', 'he said the attack had been repulsed employing this military term to describe what had occurred to his regiment but in reality he did not himself know what had happened during that half hour to the troops entrusted to him and could not say with certainty whether the attack had been repulsed or his regiment had been broken up', 'all he knew was that at the commencement of the action balls and shells began flying all over his regiment and hitting men and that afterwards someone had shouted cavalry and our men had begun firing', 'they were still firing not at the cavalry which had disappeared but at french infantry who had come into the hollow and were firing at our men']

# %% [markdown]
# ### Step 6
# Now we break each sentence into words, and store these words as a list. We traverse this list and drop the unwanted words.

# %%
def choose_words(s):
    return [w for w in s.split() if len(w) > 2 and w not in fluff]

# %%
wp_text_stage4 = [choose_words(sentence) for sentence in wp_text_stage3]
print(wp_text_stage4[4000:4010])
# Out:
# [['whole', 'air', 'reeked', 'smoke'], ['excited', 'faces', 'soldiers', 'were', 'blackened'], ['were', 'using', 'their', 'ramrods', 'others', 'putting', 'powder', 'touchpans', 'taking', 'charges', 'their', 'pouches', 'others', 'were', 'firing', 'were', 'firing', 'could', 'not', 'seen', 'smoke', 'was', 'wind', 'carry', 'away'], ['pleasant', 'humming', 'whistling', 'bullets', 'were', 'often', 'heard'], ['thought', 'prince', 'andrew', 'approaching', 'crowd', 'soldiers'], ['can', 'attack', 'are', 'not', 'moving', 'can', 'square', 'are', 'not', 'drawn', 'commander', 'regiment', 'thin', 'feeble', 'looking', 'old', 'man', 'pleasant', 'smile', 'eyelids', 'drooping', 'half', 'old', 'eyes', 'giving', 'mild', 'expression', 'rode', 'bagratión', 'welcomed', 'host', 'welcomes', 'honored', 'guest'], ['reported', 'regiment', 'had', 'been', 'attacked', 'french', 'cavalry', 'attack', 'had', 'been', 'repulsed', 'had', 'lost', 'half', 'men'], ['said', 'attack', 'had', 'been', 'repulsed', 'employing', 'military', 'term', 'describe', 'had', 'occurred', 'regiment', 'reality', 'did', 'not', 'know', 'had', 'happened', 'half', 'hour', 'troops', 'entrusted', 'could', 'not', 'say', 'certainty', 'whether', 'attack', 'had', 'been', 'repulsed', 'regiment', 'had', 'been', 'broken'], ['knew', 'was', 'commencement', 'action', 'balls', 'shells', 'began', 'flying', 'regiment', 'hitting', 'men', 'afterwards', 'had', 'shouted', 'cavalry', 'men', 'had', 'begun', 'firing'], ['were', 'still', 'firing', 'not', 'cavalry', 'had', 'disappeared', 'french', 'infantry', 'had', 'come', 'hollow', 'were', 'firing', 'men']]

# %%
print(len(wp_text_stage4))
# Out:
# 26313

# %% [markdown]
# ### Step 7
# We convert the words to common stem -- that is we do not want to consider "run", "runs", "running" as separate words

# %%
from nltk.stem.snowball import SnowballStemmer
stemmer = SnowballStemmer("english")
print(stemmer.stem("running"), stemmer.stem("run"), stemmer.stem("runs"), stemmer.stem("runner"))
print(stemmer.stem("guns"), stemmer.stem("gun"), stemmer.stem("gunned"), stemmer.stem("gunning"))
# Out:
# run run run runner
# gun gun gun gun

# %%
def stem_list(wordlist):
    return [stemmer.stem(word) for word in wordlist]
for n in range(4000, 4010):
    print(wp_text_stage4[n], stem_list(wp_text_stage4[n]))
# Out:
# ['whole', 'air', 'reeked', 'smoke'] ['whole', 'air', 'reek', 'smoke']
# ['excited', 'faces', 'soldiers', 'were', 'blackened'] ['excit', 'face', 'soldier', 'were', 'blacken']
# ['were', 'using', 'their', 'ramrods', 'others', 'putting', 'powder', 'touchpans', 'taking', 'charges', 'their', 'pouches', 'others', 'were', 'firing', 'were', 'firing', 'could', 'not', 'seen', 'smoke', 'was', 'wind', 'carry', 'away'] ['were', 'use', 'their', 'ramrod', 'other', 'put', 'powder', 'touchpan', 'take', 'charg', 'their', 'pouch', 'other', 'were', 'fire', 'were', 'fire', 'could', 'not', 'seen', 'smoke', 'was', 'wind', 'carri', 'away']
# ['pleasant', 'humming', 'whistling', 'bullets', 'were', 'often', 'heard'] ['pleasant', 'hum', 'whistl', 'bullet', 'were', 'often', 'heard']
# ['thought', 'prince', 'andrew', 'approaching', 'crowd', 'soldiers'] ['thought', 'princ', 'andrew', 'approach', 'crowd', 'soldier']
# ['can', 'attack', 'are', 'not', 'moving', 'can', 'square', 'are', 'not', 'drawn', 'commander', 'regiment', 'thin', 'feeble', 'looking', 'old', 'man', 'pleasant', 'smile', 'eyelids', 'drooping', 'half', 'old', 'eyes', 'giving', 'mild', 'expression', 'rode', 'bagratión', 'welcomed', 'host', 'welcomes', 'honored', 'guest'] ['can', 'attack', 'are', 'not', 'move', 'can', 'squar', 'are', 'not', 'drawn', 'command', 'regiment', 'thin', 'feebl', 'look', 'old', 'man', 'pleasant', 'smile', 'eyelid', 'droop', 'half', 'old', 'eye', 'give', 'mild', 'express', 'rode', 'bagratión', 'welcom', 'host', 'welcom', 'honor', 'guest']
# ['reported', 'regiment', 'had', 'been', 'attacked', 'french', 'cavalry', 'attack', 'had', 'been', 'repulsed', 'had', 'lost', 'half', 'men'] ['report', 'regiment', 'had', 'been', 'attack', 'french', 'cavalri', 'attack', 'had', 'been', 'repuls', 'had', 'lost', 'half', 'men']
# ['said', 'attack', 'had', 'been', 'repulsed', 'employing', 'military', 'term', 'describe', 'had', 'occurred', 'regiment', 'reality', 'did', 'not', 'know', 'had', 'happened', 'half', 'hour', 'troops', 'entrusted', 'could', 'not', 'say', 'certainty', 'whether', 'attack', 'had', 'been', 'repulsed', 'regiment', 'had', 'been', 'broken'] ['said', 'attack', 'had', 'been', 'repuls', 'employ', 'militari', 'term', 'describ', 'had', 'occur', 'regiment', 'realiti', 'did', 'not', 'know', 'had', 'happen', 'half', 'hour', 'troop', 'entrust', 'could', 'not', 'say', 'certainti', 'whether', 'attack', 'had', 'been', 'repuls', 'regiment', 'had', 'been', 'broken']
# ['knew', 'was', 'commencement', 'action', 'balls', 'shells', 'began', 'flying', 'regiment', 'hitting', 'men', 'afterwards', 'had', 'shouted', 'cavalry', 'men', 'had', 'begun', 'firing'] ['knew', 'was', 'commenc', 'action', 'ball', 'shell', 'began', 'fli', 'regiment', 'hit', 'men', 'afterward', 'had', 'shout', 'cavalri', 'men', 'had', 'begun', 'fire']
# ['were', 'still', 'firing', 'not', 'cavalry', 'had', 'disappeared', 'french', 'infantry', 'had', 'come', 'hollow', 'were', 'firing', 'men'] ['were', 'still', 'fire', 'not', 'cavalri', 'had', 'disappear', 'french', 'infantri', 'had', 'come', 'hollow', 'were', 'fire', 'men']

# %%
wp_text_stage5 = [stem_list(s) for s in wp_text_stage4]
print(wp_text_stage5[4000:4010])
# Out:
# [['whole', 'air', 'reek', 'smoke'], ['excit', 'face', 'soldier', 'were', 'blacken'], ['were', 'use', 'their', 'ramrod', 'other', 'put', 'powder', 'touchpan', 'take', 'charg', 'their', 'pouch', 'other', 'were', 'fire', 'were', 'fire', 'could', 'not', 'seen', 'smoke', 'was', 'wind', 'carri', 'away'], ['pleasant', 'hum', 'whistl', 'bullet', 'were', 'often', 'heard'], ['thought', 'princ', 'andrew', 'approach', 'crowd', 'soldier'], ['can', 'attack', 'are', 'not', 'move', 'can', 'squar', 'are', 'not', 'drawn', 'command', 'regiment', 'thin', 'feebl', 'look', 'old', 'man', 'pleasant', 'smile', 'eyelid', 'droop', 'half', 'old', 'eye', 'give', 'mild', 'express', 'rode', 'bagratión', 'welcom', 'host', 'welcom', 'honor', 'guest'], ['report', 'regiment', 'had', 'been', 'attack', 'french', 'cavalri', 'attack', 'had', 'been', 'repuls', 'had', 'lost', 'half', 'men'], ['said', 'attack', 'had', 'been', 'repuls', 'employ', 'militari', 'term', 'describ', 'had', 'occur', 'regiment', 'realiti', 'did', 'not', 'know', 'had', 'happen', 'half', 'hour', 'troop', 'entrust', 'could', 'not', 'say', 'certainti', 'whether', 'attack', 'had', 'been', 'repuls', 'regiment', 'had', 'been', 'broken'], ['knew', 'was', 'commenc', 'action', 'ball', 'shell', 'began', 'fli', 'regiment', 'hit', 'men', 'afterward', 'had', 'shout', 'cavalri', 'men', 'had', 'begun', 'fire'], ['were', 'still', 'fire', 'not', 'cavalri', 'had', 'disappear', 'french', 'infantri', 'had', 'come', 'hollow', 'were', 'fire', 'men']]

# %% [markdown]
# ### Step 8
# We now build a word2vec model with this corpus.

# %%
import gensim
from gensim.models import Word2Vec
from gensim.models import word2vec
from gensim.models import Phrases
import logging

# %%
num_features = 300    # Word vector dimensionality                      
min_word_count = 50   # Minimum word count                        
num_workers = 4       # Number of threads to run in parallel
context = 6           # Context window size                                                                                    
downsampling = 1e-3   # Downsample setting for frequent words

# %%
wp = word2vec.Word2Vec(wp_text_stage5, workers=num_workers, \
            size=num_features, min_count = min_word_count, \
            window = context, sample = downsampling)

# %%
wp.init_sims(replace=True)

# %%
wp.corpus_count
# Out:
# 26313

# %%
len(wp.wv.vocab.keys())
# Out:
# 1088

# %%
sorted(list(wp.wv.vocab))
# Out:
# ['1812',
#  'abandon',
#  'abl',
#  'accept',
#  'accompani',
#  'accord',
#  'account',
#  'acquaint',
#  'act',
#  'action',
#  'activ',
#  'ad',
#  'address',
#  'adjut',
#  'admit',
#  'advanc',
#  'advantag',
#  'affair',
#  'affect',
#  'afraid',
#  'again',
#  'age',
#  'agit',
#  'ago',
#  'agre',
#  'aid',
#  'aim',
#  'air',
#  'alexand',
#  'allow',
#  'almost',
#  'alon',
#  'alpátych',
#  'alreadi',
#  'also',
#  'alway',
#  'amus',
#  'anatol',
#  'andrew',
#  'angri',
#  'angrili',
#  'anim',
#  'anna',
#  'announc',
#  'answer',
#  'anxious',
#  'apart',
#  'appar',
#  'appear',
#  'appoint',
#  'approach',
#  'approv',
#  'are',
#  'arm',
#  'armi',
#  'arrang',
#  'arriv',
#  'artilleri',
#  'asham',
#  'asid',
#  'ask',
#  'asleep',
#  'assum',
#  'assur',
#  'attack',
#  'attend',
#  'attent',
#  'attract',
#  'austerlitz',
#  'austrian',
#  'author',
#  'avoid',
#  'await',
#  'away',
#  'awkward',
#  'back',
#  'bad',
#  'bagratión',
#  'balashëv',
#  'bald',
#  'ball',
#  'barclay',
#  'bare',
#  'battalion',
#  'batteri',
#  'battl',
#  'be',
#  'bear',
#  'beat',
#  'beauti',
#  'becam',
#  'becom',
#  'bed',
#  'been',
#  'beg',
#  'began',
#  'begin',
#  'begun',
#  'believ',
#  'belong',
#  'bennigsen',
#  'bent',
#  'berg',
#  'best',
#  'better',
#  'bezúkhov',
#  'big',
#  'bilíbin',
#  'bit',
#  'black',
#  'blame',
#  'blood',
#  'blow',
#  'blue',
#  'blush',
#  'bodi',
#  'bold',
#  'bolkónski',
#  'bonapart',
#  'book',
#  'boot',
#  'borodinó',
#  'borzoi',
#  'borí',
#  'bound',
#  'bourienn',
#  'bow',
#  'box',
#  'boy',
#  'break',
#  'breath',
#  'bridg',
#  'bright',
#  'brilliant',
#  'bring',
#  'broad',
#  'broke',
#  'broken',
#  'brother',
#  'brought',
#  'burn',
#  'burst',
#  'busi',
#  'call',
#  'calm',
#  'came',
#  'camp',
#  'campaign',
#  'can',
#  'candl',
#  'cannon',
#  'cannot',
#  'cap',
#  'capit',
#  'captain',
#  'captur',
#  'card',
#  'care',
#  'carri',
#  'carriag',
#  'cart',
#  'case',
#  'caught',
#  'caus',
#  'cavalri',
#  'ceas',
#  'center',
#  'certain',
#  'chair',
#  'chanc',
#  'chang',
#  'chapter',
#  'charact',
#  'charm',
#  'cheek',
#  'cheer',
#  'chief',
#  'child',
#  'children',
#  'church',
#  'circl',
#  'circumst',
#  'citi',
#  'clean',
#  'clear',
#  'clever',
#  'cloak',
#  'clock',
#  'close',
#  'cloth',
#  'cloud',
#  'club',
#  'coat',
#  'cold',
#  'collect',
#  'colonel',
#  'column',
#  'come',
#  'comfort',
#  'command',
#  'common',
#  'compani',
#  'companion',
#  'complet',
#  'comrad',
#  'conceal',
#  'concept',
#  'conclud',
#  'condit',
#  'confid',
#  'confus',
#  'connect',
#  'conscious',
#  'consid',
#  'consist',
#  'continu',
#  'contrari',
#  'convers',
#  'convinc',
#  'corner',
#  'cossack',
#  'could',
#  'council',
#  'count',
#  'countess',
#  'countri',
#  'cours',
#  'court',
#  'cover',
#  'cri',
#  'cross',
#  'crowd',
#  'cut',
#  'danc',
#  'danger',
#  'dare',
#  'dark',
#  'daughter',
#  'day',
#  'dead',
#  'deal',
#  'dear',
#  'death',
#  'decid',
#  'deep',
#  'definit',
#  'delight',
#  'demand',
#  'denísov',
#  'depend',
#  'describ',
#  'desir',
#  'destroy',
#  'detach',
#  'detail',
#  'devil',
#  'devot',
#  'did',
#  'didn',
#  'die',
#  'differ',
#  'difficult',
#  'difficulti',
#  'dine',
#  'dinner',
#  'direct',
#  'discuss',
#  'distanc',
#  'distinct',
#  'distinguish',
#  'divis',
#  'dmítrievna',
#  'do',
#  'doctor',
#  'doe',
#  'dog',
#  'don',
#  'done',
#  'door',
#  'doubt',
#  'drag',
#  'draw',
#  'drawn',
#  'dread',
#  'dream',
#  'dress',
#  'drew',
#  'drink',
#  'drive',
#  'dron',
#  'drop',
#  'drove',
#  'dull',
#  'duti',
#  'dólokhov',
#  'eager',
#  'ear',
#  'earli',
#  'earth',
#  'eat',
#  'effect',
#  'effort',
#  'elder',
#  'els',
#  'embrac',
#  'emperor',
#  'empti',
#  'end',
#  'enemi',
#  'engag',
#  'enjoy',
#  'enorm',
#  'enter',
#  'equal',
#  'escap',
#  'especi',
#  'estat',
#  'even',
#  'event',
#  'ever',
#  'everi',
#  'everyth',
#  'everywher',
#  'evid',
#  'examin',
#  'excel',
#  'excit',
#  'exclaim',
#  'execut',
#  'exist',
#  'expect',
#  'experi',
#  'experienc',
#  'explain',
#  'express',
#  'eye',
#  'face',
#  'fact',
#  'fall',
#  'fallen',
#  'famili',
#  'familiar',
#  'fanci',
#  'far',
#  'farther',
#  'fate',
#  'father',
#  'fear',
#  'feel',
#  'feet',
#  'fell',
#  'fellow',
#  'felt',
#  'field',
#  'fight',
#  'figur',
#  'fill',
#  'final',
#  'find',
#  'fine',
#  'finger',
#  'finish',
#  'fire',
#  'firm',
#  'first',
#  'fit',
#  'five',
#  'fix',
#  'flank',
#  'fli',
#  'floor',
#  'flush',
#  'follow',
#  'fond',
#  'fool',
#  'foot',
#  'forc',
#  'forest',
#  'forget',
#  'forgiv',
#  'forgotten',
#  'form',
#  'former',
#  'forward',
#  'found',
#  'four',
#  'free',
#  'freedom',
#  'french',
#  'frenchman',
#  'fresh',
#  'friend',
#  'frighten',
#  'front',
#  'frown',
#  'full',
#  'further',
#  'futur',
#  'gallop',
#  'garden',
#  'gate',
#  'gather',
#  'gave',
#  'gaze',
#  'general',
#  'genius',
#  'gentl',
#  'gentlemen',
#  'german',
#  'gestur',
#  'get',
#  'girl',
#  'give',
#  'given',
#  'glad',
#  'glanc',
#  'glass',
#  'glitter',
#  'go',
#  'god',
#  'gone',
#  'good',
#  'got',
#  'govern',
#  'governor',
#  'grand',
#  'gray',
#  'great',
#  'greater',
#  'greet',
#  'grew',
#  'ground',
#  'group',
#  'grow',
#  'grown',
#  'guard',
#  'guest',
#  'gun',
#  'gutenberg',
#  'habit',
#  'had',
#  'hair',
#  'half',
#  'hall',
#  'halt',
#  'hand',
#  'handsom',
#  'happen',
#  'happi',
#  'hard',
#  'harm',
#  'has',
#  'hastili',
#  'hat',
#  'have',
#  'head',
#  'health',
#  'hear',
#  'heard',
#  'heart',
#  'heaven',
#  'heavi',
#  'held',
#  'help',
#  'here',
#  'hero',
#  'hide',
#  'high',
#  'higher',
#  'highest',
#  'hill',
#  'hippolyt',
#  'histor',
#  'histori',
#  'historian',
#  'hold',
#  'home',
#  'honor',
#  'hope',
#  'horror',
#  'hors',
#  'hospit',
#  'hot',
#  'hour',
#  'hous',
#  'how',
#  'howev',
#  'human',
#  'hundr',
#  'hunt',
#  'hurrah',
#  'hurri',
#  'husband',
#  'hussar',
#  'hut',
#  'hélène',
#  'icon',
#  'idea',
#  'ill',
#  'imagin',
#  'immedi',
#  'import',
#  'imposs',
#  'impress',
#  'increas',
#  'indic',
#  'inevit',
#  'infantri',
#  'influenc',
#  'inform',
#  'inquir',
#  'insist',
#  'instant',
#  'instead',
#  'instruct',
#  'intend',
#  'intent',
#  'interest',
#  'interrupt',
#  'invit',
#  'involuntarili',
#  'irrit',
#  'join',
#  'joke',
#  'journey',
#  'joy',
#  'judg',
#  'juli',
#  'jump',
#  'just',
#  'karatáev',
#  'keep',
#  'kept',
#  'kill',
#  'kind',
#  'king',
#  'kiss',
#  'knee',
#  'knew',
#  'know',
#  'known',
#  'kurágin',
#  'kutúzov',
#  'lad',
#  'ladi',
#  'laid',
#  'larg',
#  'last',
#  'late',
#  'later',
#  'latter',
#  'laugh',
#  'laughter',
#  'law',
#  'lay',
#  'lead',
#  'lean',
#  'learn',
#  'least',
#  'leav',
#  'led',
#  'left',
#  'leg',
#  'less',
#  'let',
#  'letter',
#  'lie',
#  'life',
#  'lift',
#  'light',
#  'like',
#  'line',
#  'lip',
#  'listen',
#  'lit',
#  'littl',
#  'live',
#  'long',
#  'longer',
#  'look',
#  'lord',
#  'lose',
#  'loss',
#  'lost',
#  'loud',
#  'love',
#  'low',
#  'lower',
#  'madam',
#  'made',
#  'mademoisell',
#  'maid',
#  'majesti',
#  'major',
#  'make',
#  'mamma',
#  'man',
#  'manag',
#  'manner',
#  'march',
#  'mari',
#  'marri',
#  'marriag',
#  'marshal',
#  'mason',
#  'mass',
#  'master',
#  'matter',
#  'may',
#  'mean',
#  'meant',
#  'meet',
#  'member',
#  'memori',
#  'men',
#  'mention',
#  'mere',
#  'merri',
#  'met',
#  'michael',
#  'middl',
#  'might',
#  'mikháylovna',
#  'mile',
#  'militari',
#  'mind',
#  'minist',
#  'minut',
#  'miss',
#  'moment',
#  'mon',
#  'money',
#  'month',
#  'morn',
#  'moscow',
#  'mother',
#  'mount',
#  'mouth',
#  'move',
#  'movement',
#  'much',
#  'murat',
#  'music',
#  'must',
#  'mustach',
#  'mutter',
#  'mysteri',
#  'márya',
#  'name',
#  'napoleon',
#  'nation',
#  'natur',
#  'natásha',
#  'near',
#  'nearer',
#  'necess',
#  'necessari',
#  'neck',
#  'need',
#  'nesvítski',
#  'never',
#  'new',
#  'news',
#  'next',
#  'nichola',
#  'night',
#  'nod',
#  'nonsens',
#  'nose',
#  'not',
#  'note',
#  'notic',
#  'now',
#  'number',
#  'nurs',
#  'object',
#  'observ',
#  'obtain',
#  'occupi',
#  'occur',
#  'offer',
#  'offic',
#  'offici',
#  'often',
#  'old',
#  'onc',
#  'one',
#  'onli',
#  'open',
#  'opinion',
#  'order',
#  'other',
#  'ought',
#  'out',
#  'pace',
#  'pack',
#  'pain',
#  'pale',
#  'paper',
#  'part',
#  'parti',
#  'particular',
#  'pass',
#  'passag',
#  'passion',
#  'path',
#  'paus',
#  'pay',
#  'peac',
#  'peasant',
#  'peculiar',
#  'peopl',
#  'perfect',
#  'perform',
#  'perhap',
#  'person',
#  'petersburg',
#  'physic',
#  'pierr',
#  'piti',
#  'place',
#  'plain',
#  'plan',
#  'play',
#  'pleas',
#  'pleasant',
#  'pleasur',
#  'point',
#  'polish',
#  'polit',
#  'poor',
#  'porch',
#  'posit',
#  'possess',
#  'possibl',
#  'post',
#  'power',
#  'pray',
#  'prayer',
#  'prepar',
#  'presenc',
#  'present',
#  'press',
#  'pretti',
#  'previous',
#  'princ',
#  'princess',
#  'prison',
#  'probabl',
#  'produc',
#  'project',
#  'promis',
#  'propos',
#  'prove',
#  'pull',
#  'purpos',
#  'push',
#  'put',
#  'pávlovna',
#  'pétya',
#  'quarter',
#  'question',
#  'quick',
#  'quiet',
#  'quit',
#  'rais',
#  'ran',
#  'rank',
#  'rapid',
#  'rather',
#  'reach',
#  'read',
#  'readi',
#  'real',
#  'realiz',
#  'realli',
#  'reason',
#  'recal',
#  'receiv',
#  'recept',
#  'recogn',
#  'red',
#  'refer',
#  'reflect',
#  'refus',
#  'regard',
#  'regiment',
#  'relat',
#  'remain',
#  'remark',
#  'rememb',
#  'remov',
#  'repeat',
#  'repli',
#  'report',
#  'reproach',
#  'resolut',
#  'respect',
#  'rest',
#  'result',
#  'retir',
#  'retreat',
#  'return',
#  'rich',
#  'ride',
#  'right',
#  'ring',
#  'rise',
#  'river',
#  'road',
#  'rode',
#  'roll',
#  'room',
#  'rose',
#  'rostopchín',
#  'rostóv',
#  'rubl',
#  'ruin',
#  'rule',
#  'run',
#  'rush',
#  'russia',
#  'russian',
#  'saber',
#  'sacrific',
#  'sad',
#  'saddl',
#  'said',
#  'sake',
#  'same',
#  'sat',
#  'satisfi',
#  'save',
#  'saw',
#  'say',
#  'scarc',
#  'scienc',
#  'scream',
#  'seat',
#  'second',
#  'secret',
#  'see',
#  'seek',
#  'seem',
#  'seen',
#  'seiz',
#  'send',
#  'sens',
#  'sent',
#  'separ',
#  'serf',
#  'serious',
#  'serv',
#  'servant',
#  'servic',
#  'set',
#  'settl',
#  'seven',
#  'sever',
#  'shall',
#  'share',
#  'shed',
#  'shook',
#  'short',
#  'shot',
#  'should',
#  'shoulder',
#  'shout',
#  'show',
#  'shown',
#  'sick',
#  'side',
#  'sigh',
#  'sight',
#  'sign',
#  'signific',
#  'silenc',
#  'silent',
#  'simpl',
#  'simpli',
#  'sing',
#  'singl',
#  'sir',
#  'sister',
#  'sit',
#  'six',
#  'sky',
#  'sleep',
#  'sleigh',
#  'slight',
#  'small',
#  'smile',
#  'smoke',
#  'smolénsk',
#  'snow',
#  'sob',
#  'societi',
#  'sofa',
#  'soft',
#  'soldier',
#  'solemn',
#  'sometim',
#  'son',
#  'soon',
#  'sorri',
#  'sorrow',
#  'sort',
#  'soul',
#  'sound',
#  'sovereign',
#  'speak',
#  'special',
#  'spectacl',
#  'spent',
#  'speránski',
#  'spirit',
#  'spite',
#  'splendid',
#  'spoke',
#  'spoken',
#  'spot',
#  'spread',
#  'squadron',
#  'staff',
#  'stand',
#  'start',
#  'state',
#  'station',
#  'stay',
#  'step',
#  'stern',
#  'still',
#  'stood',
#  'stop',
#  'stori',
#  'straight',
#  'strang',
#  'street',
#  'strength',
#  'strong',
#  'struck',
#  'struggl',
#  'studi',
#  'stupid',
#  'subject',
#  'success',
#  'sudden',
#  'suffer',
#  'suggest',
#  'suit',
#  'sun',
#  'supper',
#  'suppos',
#  'sure',
#  'surpris',
#  'surround',
#  'sway',
#  'sónya',
#  'tabl',
#  'take',
#  'taken',
#  'talk',
#  'tall',
#  'tea',
#  'tear',
#  'tell',
#  'ten',
#  'tender',
#  'term',
#  'terribl',
#  'thank',
#  'their',
#  'then',
#  'therefor',
#  'these',
#  'thin',
#  'thing',
#  'think',
#  'third',
#  'thirti',
#  'those',
#  'thought',
#  'thousand',
#  'three',
#  'threw',
#  'throw',
#  'time',
#  'timid',
#  'today',
#  'togeth',
#  'told',
#  'tomorrow',
#  'tone',
#  'too',
#  'took',
#  'torment',
#  'touch',
#  'town',
#  'train',
#  'travel',
#  ...]

# %% [markdown]
# ### Step 9
# Let us save this so that we can continue

# %%
wp.wv.save_word2vec_format('wp.bin')

# %%
import numpy as np
X = np.array([wp.wv.get_vector(w) for w in wp.wv.vocab])
X
# Out:
# array([[ 0.05986286,  0.00761258,  0.08367426, ...,  0.13716994,
#          0.01763026, -0.03512678],
#        [ 0.0740163 ,  0.0260452 ,  0.0629072 , ...,  0.13580059,
#          0.01269948, -0.06774356],
#        [ 0.08516932,  0.05439915,  0.08361565, ...,  0.10415892,
#          0.04276372, -0.03500239],
#        ...,
#        [ 0.06150025,  0.07913902,  0.0766716 , ...,  0.02518934,
#          0.03920969,  0.04372467],
#        [ 0.06429806, -0.01111223,  0.06246019, ...,  0.13038577,
#         -0.0108255 , -0.01920319],
#        [ 0.07929389,  0.05132754,  0.07937398, ...,  0.09993965,
#          0.03177457, -0.01217923]], dtype=float32)

# %% [markdown]
# **Excerise 1:** Apply Hierarchical Clustering

# %%
def plot_clustering(X_red, X, labels, title=None):
    x_min, x_max = np.min(X_red, axis=0), np.max(X_red, axis=0)
    X_red = (X_red - x_min) / (x_max - x_min)

    plt.figure(figsize=(6, 4))
    for i in range(X_red.shape[0]):
        plt.text(X_red[i, 0], X_red[i, 1], str(labels[i]),
                 color=plt.cm.spectral(labels[i] / 10.),
                 fontdict={'weight': 'bold', 'size': 9})

    plt.xticks([])
    plt.yticks([])
    if title is not None:
        plt.title(title, size=17)
    plt.axis('off')
    plt.tight_layout()

# %%
###Your code here
from sklearn import manifold
from time import time
import numpy as np
from scipy import ndimage
from matplotlib import pyplot as plt

print("Computing embedding")
X_red = manifold.SpectralEmbedding(n_components=2).fit_transform(X)
print("Done.")

from sklearn.cluster import AgglomerativeClustering
clustering = AgglomerativeClustering(linkage='ward', n_clusters=15) # Classify the novel into 15 clusters - Oracle
t0 = time()
clustering.fit(X_red)

linkage = 'ward'

print("%s : %.2fs" % (linkage, time() - t0))
plot_clustering(X_red, X, clustering.labels_, "Distribution of clusters" )

plt.show()
# Out:
# Computing embedding
# Done.
# ward : 0.03s

# %%
len(clustering.labels_), len(X), len(X_red)
# Out:
# (1088, 1088, 1088)

# %% [markdown]
# **Excerise 2:** Apply PCA on the data

# %%
import random
picker = list(range(len(X)))
random.shuffle(picker) 
indices = picker[:10]
y = list(wp.wv.vocab.keys())

# Select random 10 words to be displayed in the 2D space
y_cut = [y[i] for i in indices]
X_cut = X[indices]

print('Selected random words:')
for i, w in enumerate(y_cut):
    print(i, w)
# Out:
# Selected random words:
# 0 physic
# 1 serious
# 2 wheel
# 3 dinner
# 4 sad
# 5 fit
# 6 pale
# 7 smolénsk
# 8 answer
# 9 too

# %%
### Your code here

from sklearn import decomposition
import numpy as np
pca = decomposition.PCA(n_components=2)
#fit_transform fits the data and reduces the dimensionality too. 
X_pca = pca.fit_transform(X)

y_num = range(len(y_cut))

plot_clustering(X_pca[indices], X[indices], y_num, title='PCA')

# %% [markdown]
# **Excerise 3:** Apply ISOMAP on the data

# %%
### Your code here

iso = manifold.Isomap(n_neighbors=6, n_components=2)
iso.fit(X)
manifold_data = iso.transform(X)

plot_clustering(manifold_data[indices], X[indices], y_num, title='ISOMAP')

# %% [markdown]
# **Excerise 4:** Apply LLE on the data

# %%
### Your code here
lle_data, _ = manifold.locally_linear_embedding(X, n_neighbors=12,
                                             n_components=2)
plot_clustering(lle_data[indices], X[indices], y_num, title='LLE')

# %% [markdown]
# **Excerise 5:** Apply T-SNE on the data

# %%
### Your code here
tsne_data = manifold.TSNE(n_components=2).fit_transform(X)

plot_clustering(tsne_data[indices], X[indices], y_num, title='t-SNE')
