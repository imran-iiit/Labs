# %% [markdown]
# # Experiment 0 (<15 minutes)

# %% [markdown]
#  Only pen and paper (perhaps with access to a scientific calculator)

# %% [markdown]
# Objective: How do we determine the best split? (basically we want to know the simple math
# behind a typical Decision Tree e.g. CART or C4.5 (the standard DT libraries available in Python).
# Why are Decision Trees typically fast?
# One of the building blocks of Information Gain (IG) is the entropy. One simple way is using the "Shannon's entropy" defined by the below formula:

# %%
from IPython.display import Image
Image(filename='Shannon.png')

# %% [markdown]
# # Calculate the entropies for the below image:

# %%
from IPython.display import Image
Image(filename='Calculate_entropies.png')
